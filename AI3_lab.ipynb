# %% [markdown]
# <a href="https://colab.research.google.com/github/IrynaBarnych/AI3_lab/blob/lab/AI3_lab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Імпорт модуля pandas

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Дані про пасажирів корабля:
#
# pclass -- клас білета(перший, другий або третій)
# sex -- стать
# age -- вік
# sibsp -- кількість братів\сестер та чоловіків\дружин на борту
# parch -- кількість дітей та батьків на борту
# fare -- вартість поїздки
# embarked -- Порт посадки (C = Шербур, Q = Квінстаун, S = Саутгемптон)

# %% [markdown]
# Завдання 1
# Вивести загальну інформацію про таблицю: кількість рядків та стовпців, назви стовпців та їхній тип даних, в яких стовпцях є пропущені значення

# %%
df = pd.DataFrame({
    'pclass': [
        'перший',
        'другий',
        'третій',
        'перший',
        'другий'],
    'sex': [
        'чоловік',
        'жінка',
        'жінка',
        'чоловік',
        'жінка'],
    'age': [
        38,
        26,
        35,
        45,
        3],
    'sibsp': [
        1,
        1,
        0,
        1,
        0],
    'parch': [
        0,
        2,
        1,
        1,
        0],
    'fare': [
        71.2833,
        26.0,
        7.125,
        61.3792,
        73.5],
    'embarked': [
        'C',
        'S',
        'Q',
        'C',
        'S']
})

# %%
df
# Out:
#    pclass      sex  age  sibsp  parch     fare embarked
# 0  перший  чоловік   38      1      0  71.2833        C
# 1  другий    жінка   26      1      2  26.0000        S
# 2  третій    жінка   35      0      1   7.1250        Q
# 3  перший  чоловік   45      1      1  61.3792        C
# 4  другий    жінка    3      0      0  73.5000        S

# %% [markdown]
# Завдання 2
# Скільки пасажирів сіло у Квінстауні?

# %%
passengers_in_queenstown = df ['embarked'] == 'Q'

passengers_in_queenstown = (df['embarked'] == 'Q').sum()
df
# Out:
#    pclass      sex  age  sibsp  parch     fare embarked
# 0  перший  чоловік   38      1      0  71.2833        C
# 1  другий    жінка   26      1      2  26.0000        S
# 2  третій    жінка   35      0      1   7.1250        Q
# 3  перший  чоловік   45      1      1  61.3792        C
# 4  другий    жінка    3      0      0  73.5000        S

# %% [markdown]
# Завдання 3
# Виведіть стать, вік та вартість поїздки для пасажирів з білетом першого класу

# %%
first_class_passengers = df.loc[df["pclass"] == 'перший', ["sex", "age", "fare"]]
df
# Out:
#    pclass      sex  age  sibsp  parch     fare embarked
# 0  перший  чоловік   38      1      0  71.2833        C
# 1  другий    жінка   26      1      2  26.0000        S
# 2  третій    жінка   35      0      1   7.1250        Q
# 3  перший  чоловік   45      1      1  61.3792        C
# 4  другий    жінка    3      0      0  73.5000        S

# %% [markdown]
# Завдання 4
# Ввиведіть дані про неповнолітніх чоловіків з Шербура

# %%
male_from_cherbourg = df.loc[(df['sex'] == 'чоловік') & (df['age'] < 18) & (df['embarked'] == 'C')]

df
# Out:
#    pclass      sex  age  sibsp  parch     fare embarked
# 0  перший  чоловік   38      1      0  71.2833        C
# 1  другий    жінка   26      1      2  26.0000        S
# 2  третій    жінка   35      0      1   7.1250        Q
# 3  перший  чоловік   45      1      1  61.3792        C
# 4  другий    жінка    3      0      0  73.5000        S

# %% [markdown]
# Завдання 5
# Створіть новий стовпчик relatives -- загальна кількість родичів на борту для кожного пасажира

# %%
df['relatives'] = df['sibsp'] + df['parch']
df
# Out:
#    pclass      sex  age  sibsp  parch     fare embarked  relatives
# 0  перший  чоловік   38      1      0  71.2833        C          1
# 1  другий    жінка   26      1      2  26.0000        S          3
# 2  третій    жінка   35      0      1   7.1250        Q          1
# 3  перший  чоловік   45      1      1  61.3792        C          2
# 4  другий    жінка    3      0      0  73.5000        S          0

# %% [markdown]
# Завдання 6
# Видаліть стовпчик, в якому найбільше пропусків. Якщо пропущені значення ще залишаться, видаліть рядки з пропусками

# %%
column = df.isnull().sum().idxmax()


#df = df.drop(column)
print(column)

df
# Out:
# sex
#        sex  age  sibsp  parch     fare embarked  relatives
# 0  чоловік   38      1      0  71.2833        C          1
# 1    жінка   26      1      2  26.0000        S          3
# 2    жінка   35      0      1   7.1250        Q          1
# 3  чоловік   45      1      1  61.3792        C          2
# 4    жінка    3      0      0  73.5000        S          0
